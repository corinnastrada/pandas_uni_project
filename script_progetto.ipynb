# %% [markdown]
# # PROGETTO 2021 - COMPUTER SCIENCE

# %% [markdown]
# ### Importo la libreria pandas

# %%
import pandas as pd

# %% [markdown]
# ### Per prima cosa, leggo tutti i files

# %%
book_ratings = pd.read_csv("C:/Users/HP/F_COMPUTER_SCIENCE/progetto/book-ratings.csv", encoding = "latin-1", delimiter = ";")

# %%
book_ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
books = pd.read_csv("C:/Users/HP/F_COMPUTER_SCIENCE/progetto/Books.csv", encoding = 'latin-1', delimiter = ";",  
                    low_memory=False)

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271354  0440400988                         There's a Bat in Bunk Five
# 271355  0525447644                            From One to One Hundred
# 271356  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271357  0192126040                        Republic (World's Classics)
# 271358  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271354        Paula Danziger                1988
# 271355            Teri Sloat                1991
# 271356      Christine Wicker                2004
# 271357                 Plato                1996
# 271358   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271354                   Random House Childrens Pub (Mm)
# 271355                                      Dutton Books
# 271356                                HarperSanFrancisco
# 271357                           Oxford University Press
# 271358  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271354  http://images.amazon.com/images/P/0440400988.0...
# 271355  http://images.amazon.com/images/P/0525447644.0...
# 271356  http://images.amazon.com/images/P/006008667X.0...
# 271357  http://images.amazon.com/images/P/0192126040.0...
# 271358  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271354  http://images.amazon.com/images/P/0440400988.0...
# 271355  http://images.amazon.com/images/P/0525447644.0...
# 271356  http://images.amazon.com/images/P/006008667X.0...
# 271357  http://images.amazon.com/images/P/0192126040.0...
# 271358  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271354  http://images.amazon.com/images/P/0440400988.0...
# 271355  http://images.amazon.com/images/P/0525447644.0...
# 271356  http://images.amazon.com/images/P/006008667X.0...
# 271357  http://images.amazon.com/images/P/0192126040.0...
# 271358  http://images.amazon.com/images/P/0767409752.0...
#
# [271359 rows x 8 columns]

# %%
goodbooks_ratings = pd.read_csv("C:/Users/HP/F_COMPUTER_SCIENCE/progetto/goodbooks-ratings.csv", encoding = 'latin-1')

# %%
goodbooks_ratings
# Out:
#     user_id  book_id  rating
# 0         1      258       5
# 1         2     4081       4
# 2         2      260       5
# 3         2     9296       5
# 4         2     2318       3
# ..      ...      ...     ...
# 94        4      184       4
# 95        4      495       4
# 96        4      350       3
# 97        4      492       4
# 98        4      219       4
#
# [99 rows x 3 columns]

# %%
goodbooks = pd.read_csv("C:/Users/HP/F_COMPUTER_SCIENCE/progetto/goodbooks.csv", encoding = 'latin-1')

# %%
goodbooks
# Out:
#     book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0         1            2767052       2767052   2792775          272
# 1         2                  3             3   4640799          491
# 2         3              41865         41865   3212258          226
# 3         4               2657          2657   3275794          487
# 4         5               4671          4671    245494         1356
# ..      ...                ...           ...       ...          ...
# 94       95               5297          5297   1858012         2303
# 95       96           13536860      13536860  18034963          133
# 96       97              17245         17245   3165724         2207
# 97       98            5060378       5060378   6976108          209
# 98       99           11857408      11857408  16813814          147
#
#           isbn        isbn13                                    authors  \
# 0    439023483  9.780439e+12                            Suzanne Collins
# 1    439554934  9.780440e+12               J.K. Rowling, Mary GrandPrÃ©
# 2    316015849  9.780316e+12                            Stephenie Meyer
# 3     61120081  9.780061e+12                                 Harper Lee
# 4    743273567  9.780743e+12                        F. Scott Fitzgerald
# ..         ...           ...                                        ...
# 94   375751513  9.780376e+12             Oscar Wilde, Jeffrey Eugenides
# 95   345803507  9.780346e+12                                 E.L. James
# 96   393970124  9.780394e+12  Bram Stoker, Nina Auerbach, David J. Skal
# 97   307269981  9.780307e+12                 Stieg Larsson, Reg Keeland
# 98  1612130585  9.781612e+12                                 E.L. James
#
#     original_publication_year                            original_title  ...  \
# 0                      2008.0                          The Hunger Games  ...
# 1                      1997.0  Harry Potter and the Philosopher's Stone  ...
# 2                      2005.0                                  Twilight  ...
# 3                      1960.0                     To Kill a Mockingbird  ...
# 4                      1925.0                          The Great Gatsby  ...
# ..                        ...                                       ...  ...
# 94                     1891.0                The Picture of Dorian Gray  ...
# 95                     2012.0                        Fifty Shades Freed  ...
# 96                     1897.0                                   Dracula  ...
# 97                     2006.0               Flickan som lekte med elden  ...
# 98                     2011.0                       Fifty Shades Darker  ...
#
#    ratings_count work_ratings_count  work_text_reviews_count  ratings_1  \
# 0        4780653            4942365                   155254      66715
# 1        4602479            4800065                    75867      75504
# 2        3866839            3916824                    95009     456191
# 3        3198671            3340896                    72586      60427
# 4        2683664            2773745                    51992      86236
# ..           ...                ...                      ...        ...
# 94        590014             674551                    19647       9825
# 95        387290             610116                    25287      39079
# 96        618973             689739                    17263      11756
# 97        563994             649253                    31423       4623
# 98        552059             623340                    28052      37245
#
#     ratings_2  ratings_3  ratings_4  ratings_5  \
# 0      127936     560092    1481305    2706317
# 1      101676     455024    1156318    3011543
# 2      436802     793319     875073    1355439
# 3      117415     446835    1001952    1714267
# 4      197621     606158     936012     947718
# ..        ...        ...        ...        ...
# 94      30735     129420     246892     257679
# 95      55691     109963     140304     265079
# 96      36719     151396     246043     243825
# 97      15781      91021     258236     279592
# 98      58935     114203     150906     262051
#
#                                             image_url  \
# 0   https://images.gr-assets.com/books/1447303603m...
# 1   https://images.gr-assets.com/books/1474154022m...
# 2   https://images.gr-assets.com/books/1361039443m...
# 3   https://images.gr-assets.com/books/1361975680m...
# 4   https://images.gr-assets.com/books/1490528560m...
# ..                                                ...
# 94  https://images.gr-assets.com/books/1424596966m...
# 95  https://images.gr-assets.com/books/1336418837m...
# 96  https://images.gr-assets.com/books/1387151694m...
# 97  https://images.gr-assets.com/books/1351778881m...
# 98  https://images.gr-assets.com/books/1358266080m...
#
#                                       small_image_url
# 0   https://images.gr-assets.com/books/1447303603s...
# 1   https://images.gr-assets.com/books/1474154022s...
# 2   https://images.gr-assets.com/books/1361039443s...
# 3   https://images.gr-assets.com/books/1361975680s...
# 4   https://images.gr-assets.com/books/1490528560s...
# ..                                                ...
# 94  https://images.gr-assets.com/books/1424596966s...
# 95  https://images.gr-assets.com/books/1336418837s...
# 96  https://images.gr-assets.com/books/1387151694s...
# 97  https://images.gr-assets.com/books/1351778881s...
# 98  https://images.gr-assets.com/books/1358266080s...
#
# [99 rows x 23 columns]

# %%
users = pd.read_csv("C:/Users/HP/F_COMPUTER_SCIENCE/progetto/users.csv", encoding = 'latin-1', delimiter = ";")

# %%
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %% [markdown]
# ### 1. Normalize the location field of Users dataset, splitting into city, region, country.

# %%
for i in range(0,3):
    users[i]= users['Location'].str.split(',',expand=True)[i]
    
users = users.rename(columns={0: 'city', 1: 'region', 2: 'country' })

# %%
users
# Out:
#         User-ID                            Location   Age         city  \
# 0             1                  nyc, new york, usa   NaN          nyc
# 1             2           stockton, california, usa  18.0     stockton
# 2             3     moscow, yukon territory, russia   NaN       moscow
# 3             4           porto, v.n.gaia, portugal  17.0        porto
# 4             5  farnborough, hants, united kingdom   NaN  farnborough
# ...         ...                                 ...   ...          ...
# 278853   278854               portland, oregon, usa   NaN     portland
# 278854   278855  tacoma, washington, united kingdom  50.0       tacoma
# 278855   278856           brampton, ontario, canada   NaN     brampton
# 278856   278857           knoxville, tennessee, usa   NaN    knoxville
# 278857   278858                dublin, n/a, ireland   NaN       dublin
#
#                   region          country
# 0               new york              usa
# 1             california              usa
# 2        yukon territory           russia
# 3               v.n.gaia         portugal
# 4                  hants   united kingdom
# ...                  ...              ...
# 278853            oregon              usa
# 278854        washington   united kingdom
# 278855           ontario           canada
# 278856         tennessee              usa
# 278857               n/a          ireland
#
# [278858 rows x 6 columns]

# %% [markdown]
# #### un'altra possibile soluzione, un poco più macchinosa

# %%
##users['city']=users['Location'].str.split(',',expand=True)[0]
##users['region']=users['Location'].str.split(',',expand=True)[1]
##users['country']=users['Location'].str.split(',',expand=True)[2]

# %% [markdown]
# ### 2. For each book in the Books dataset, compute its average rating.

# %%
books_ratings = pd.merge(books, book_ratings, on = 'ISBN')

# %%
avg_rating_of_book = books_ratings.groupby(['ISBN', 'Book-Title', 'Book-Author'], as_index=False)['Book-Rating'].mean()

# %%
avg_rating_of_book.head(15)
# Out:
#           ISBN                                         Book-Title  \
# 0   0000913154  The Way Things Work: An Illustrated Encycloped...
# 1   0001010565                                    Mog's Christmas
# 2   0001046438                                               Liar
# 3   0001046713                       Twopence to Cross the Mersey
# 4   000104687X  T.S. Eliot Reading \The Wasteland\" and Other ...
# 5   0001046934                      The Prime of Miss Jean Brodie
# 6   0001047213                                   The Fighting Man
# 7   0001047647                                 First Among Equals
# 8   0001047663                                   Matter Of Honour
# 9   0001047868                                          Kidnapped
# 10  0001047973                                    Brave New World
# 11  000104799X                                        Monk's-hood
# 12  0001048082                                    Made in America
# 13  0001048473                              Nothing Can Be Better
# 14  0001049879                             Daughters of the Storm
#
#                       Book-Author  Book-Rating
# 0   C. van Amerongen (translator)          8.0
# 1                     Judith Kerr          0.0
# 2                     Stephen Fry          9.0
# 3                 Helen Forrester          0.0
# 4                      T.S. Eliot          6.0
# 5                    Muriel Spark          0.0
# 6                  Gerald Seymour          9.0
# 7                  Jeffrey Archer          0.0
# 8                  Jeffrey Archer          0.0
# 9          Robert Louis Stevenson          0.0
# 10                  Aldous Huxley          9.0
# 11                   Ellis Peters          7.5
# 12                    Bill Bryson          8.0
# 13               Barns &amp; Budd          0.0
# 14               Elizabeth Buchan          0.0

# %% [markdown]
# ### 3. For each book in the GoodBooks dataset, compute its average rating.

# %%
goodbooks[['book_id', 'isbn', 'authors', 'original_title', 'title', 'average_rating']]
# Out:
#     book_id        isbn                                    authors  \
# 0         1   439023483                            Suzanne Collins
# 1         2   439554934               J.K. Rowling, Mary GrandPrÃ©
# 2         3   316015849                            Stephenie Meyer
# 3         4    61120081                                 Harper Lee
# 4         5   743273567                        F. Scott Fitzgerald
# ..      ...         ...                                        ...
# 94       95   375751513             Oscar Wilde, Jeffrey Eugenides
# 95       96   345803507                                 E.L. James
# 96       97   393970124  Bram Stoker, Nina Auerbach, David J. Skal
# 97       98   307269981                 Stieg Larsson, Reg Keeland
# 98       99  1612130585                                 E.L. James
#
#                               original_title  \
# 0                           The Hunger Games
# 1   Harry Potter and the Philosopher's Stone
# 2                                   Twilight
# 3                      To Kill a Mockingbird
# 4                           The Great Gatsby
# ..                                       ...
# 94                The Picture of Dorian Gray
# 95                        Fifty Shades Freed
# 96                                   Dracula
# 97               Flickan som lekte med elden
# 98                       Fifty Shades Darker
#
#                                                 title  average_rating
# 0             The Hunger Games (The Hunger Games, #1)            4.34
# 1   Harry Potter and the Sorcerer's Stone (Harry P...            4.44
# 2                             Twilight (Twilight, #1)            3.57
# 3                               To Kill a Mockingbird            4.25
# 4                                    The Great Gatsby            3.89
# ..                                                ...             ...
# 94                         The Picture of Dorian Gray            4.06
# 95              Fifty Shades Freed (Fifty Shades, #3)            3.88
# 96                                            Dracula            3.98
# 97     The Girl Who Played with Fire (Millennium, #2)            4.22
# 98             Fifty Shades Darker (Fifty Shades, #2)            3.87
#
# [99 rows x 6 columns]

# %% [markdown]
# ### 4. Merge together all rows sharing the same book title, author and publisher. We will call the resulting datset merged books. The books that have not been merged together will not appear in merged books.

# %%
merged_books = books.groupby(['Book-Title', 'Book-Author', 'Publisher'], as_index=False)['ISBN'].count()

# %%
merged_books = merged_books[merged_books['ISBN']!=1]

# %%
merged_books= merged_books[['Book-Title', 'Book-Author', 'Publisher']]

# %%
merged_books
# Out:
#                                                Book-Title  \
# 41                              !%@ (A Nutshell handbook)
# 59      'A Hell of a Place to Lose a Cow': An American...
# 255     10,000 dreams interpreted: A dictionary of dreams
# 465                                      101 Famous Poems
# 713                    15 Houseplants Even You Can't Kill
# ...                                                   ...
# 265525                                                Zia
# 265526                                                Zia
# 265562                                Zimmermann Telegram
# 265625  Zoids Chaotic Century (Zoids: Chaotic Century ...
# 266117         Ã?Ã?berleben in der WÃ?ÃÂ¼ste Danakil.
#
#                     Book-Author                       Publisher
# 41                Donnalyn Frey                        O'Reilly
# 59                  Tim Brookes             National Geographic
# 255     Gustavus Hindman Miller       Barnes &amp; Nobles Books
# 465                 Roy J. Cook  McGraw-Hill/Contemporary Books
# 713                   Joe Elder               Berkley Pub Group
# ...                         ...                             ...
# 265525             Scott O'Dell               Laurel-Leaf Books
# 265526             Scott O'Dell                  Yearling Books
# 265562          Barbara Tuchman                Ballantine Books
# 265625           Michiro Ueyama                      Viz Comics
# 266117    RÃ?ÃÂ¼diger Nehberg                           Piper
#
# [4725 rows x 3 columns]

# %% [markdown]
# ### 5. For each book in merged books compute its average rating.

# %%
merged_books_ratings  = pd.merge(merged_books, books_ratings, on = ('Book-Title', 'Book-Author', 'Publisher'), how='left')
merged_books_ratings
# Out:
#                                               Book-Title  \
# 0                              !%@ (A Nutshell handbook)
# 1                              !%@ (A Nutshell handbook)
# 2      'A Hell of a Place to Lose a Cow': An American...
# 3      'A Hell of a Place to Lose a Cow': An American...
# 4      'A Hell of a Place to Lose a Cow': An American...
# ...                                                  ...
# 92851  Zoids Chaotic Century (Zoids: Chaotic Century ...
# 92852         Ã?Ã?berleben in der WÃ?ÃÂ¼ste Danakil.
# 92853         Ã?Ã?berleben in der WÃ?ÃÂ¼ste Danakil.
# 92854         Ã?Ã?berleben in der WÃ?ÃÂ¼ste Danakil.
# 92855         Ã?Ã?berleben in der WÃ?ÃÂ¼ste Danakil.
#
#                  Book-Author            Publisher        ISBN  \
# 0              Donnalyn Frey             O'Reilly  1565920465
# 1              Donnalyn Frey             O'Reilly  1565920317
# 2                Tim Brookes  National Geographic  0792276833
# 3                Tim Brookes  National Geographic  0792276833
# 4                Tim Brookes  National Geographic  0792276833
# ...                      ...                  ...         ...
# 92851         Michiro Ueyama           Viz Comics  1569317658
# 92852  RÃ?ÃÂ¼diger Nehberg                Piper  3492218091
# 92853  RÃ?ÃÂ¼diger Nehberg                Piper  3492233376
# 92854  RÃ?ÃÂ¼diger Nehberg                Piper  3492233376
# 92855  RÃ?ÃÂ¼diger Nehberg                Piper  3492233376
#
#       Year-Of-Publication                                        Image-URL-S  \
# 0                    1994  http://images.amazon.com/images/P/1565920465.0...
# 1                    1993  http://images.amazon.com/images/P/1565920317.0...
# 2                    2000  http://images.amazon.com/images/P/0792276833.0...
# 3                    2000  http://images.amazon.com/images/P/0792276833.0...
# 4                    2000  http://images.amazon.com/images/P/0792276833.0...
# ...                   ...                                                ...
# 92851                2002  http://images.amazon.com/images/P/1569317658.0...
# 92852                1994  http://images.amazon.com/images/P/3492218091.0...
# 92853                2001  http://images.amazon.com/images/P/3492233376.0...
# 92854                2001  http://images.amazon.com/images/P/3492233376.0...
# 92855                2001  http://images.amazon.com/images/P/3492233376.0...
#
#                                              Image-URL-M  \
# 0      http://images.amazon.com/images/P/1565920465.0...
# 1      http://images.amazon.com/images/P/1565920317.0...
# 2      http://images.amazon.com/images/P/0792276833.0...
# 3      http://images.amazon.com/images/P/0792276833.0...
# 4      http://images.amazon.com/images/P/0792276833.0...
# ...                                                  ...
# 92851  http://images.amazon.com/images/P/1569317658.0...
# 92852  http://images.amazon.com/images/P/3492218091.0...
# 92853  http://images.amazon.com/images/P/3492233376.0...
# 92854  http://images.amazon.com/images/P/3492233376.0...
# 92855  http://images.amazon.com/images/P/3492233376.0...
#
#                                              Image-URL-L  User-ID  Book-Rating
# 0      http://images.amazon.com/images/P/1565920465.0...   271245            0
# 1      http://images.amazon.com/images/P/1565920317.0...    87141            6
# 2      http://images.amazon.com/images/P/0792276833.0...    79186            0
# 3      http://images.amazon.com/images/P/0792276833.0...   114216            0
# 4      http://images.amazon.com/images/P/0792276833.0...   201058            0
# ...                                                  ...      ...          ...
# 92851  http://images.amazon.com/images/P/1569317658.0...    63714           10
# 92852  http://images.amazon.com/images/P/3492218091.0...   167847            5
# 92853  http://images.amazon.com/images/P/3492233376.0...   174480            0
# 92854  http://images.amazon.com/images/P/3492233376.0...   229149            8
# 92855  http://images.amazon.com/images/P/3492233376.0...   231891            0
#
# [92856 rows x 10 columns]

# %%
merged_books_ratings = merged_books_ratings.groupby(['Book-Title', 'Book-Author', 'Publisher', 'ISBN'], 
                                                    as_index=False).mean()[['Book-Title', 'Book-Author', 'Publisher',
                                                                            'ISBN', 'Book-Rating']]

# %%
merged_books_ratings.rename(columns={'Book-Rating': 'Book-Rating-Avg'}, inplace=True)

# %%
merged_books_ratings
# Out:
#                                              Book-Title  \
# 0                             !%@ (A Nutshell handbook)
# 1                             !%@ (A Nutshell handbook)
# 2     'A Hell of a Place to Lose a Cow': An American...
# 3     'A Hell of a Place to Lose a Cow': An American...
# 4     10,000 dreams interpreted: A dictionary of dreams
# ...                                                 ...
# 9906  Zoids Chaotic Century (Zoids: Chaotic Century ...
# 9907  Zoids Chaotic Century (Zoids: Chaotic Century ...
# 9908  Zoids Chaotic Century (Zoids: Chaotic Century ...
# 9909         Ã?Ã?berleben in der WÃ?ÃÂ¼ste Danakil.
# 9910         Ã?Ã?berleben in der WÃ?ÃÂ¼ste Danakil.
#
#                   Book-Author                  Publisher        ISBN  \
# 0               Donnalyn Frey                   O'Reilly  1565920317
# 1               Donnalyn Frey                   O'Reilly  1565920465
# 2                 Tim Brookes        National Geographic  0792276833
# 3                 Tim Brookes        National Geographic  0792277295
# 4     Gustavus Hindman Miller  Barnes &amp; Nobles Books  1566196256
# ...                       ...                        ...         ...
# 9906           Michiro Ueyama                 Viz Comics  1569317666
# 9907           Michiro Ueyama                 Viz Comics  1569317674
# 9908           Michiro Ueyama                 Viz Comics  1569317682
# 9909    RÃ?ÃÂ¼diger Nehberg                      Piper  3492218091
# 9910    RÃ?ÃÂ¼diger Nehberg                      Piper  3492233376
#
#       Book-Rating-Avg
# 0            6.000000
# 1            0.000000
# 2            0.000000
# 3            3.400000
# 4            7.250000
# ...               ...
# 9906        10.000000
# 9907        10.000000
# 9908        10.000000
# 9909         5.000000
# 9910         2.666667
#
# [9911 rows x 5 columns]

# %% [markdown]
# ### 6. For each book in merged books compute the minimum and maximum of the average ratings over all corresponding books in the books dataset.

# %%
merged_books_ratings[['Book-Title', 'Book-Author', 'Publisher', 'Book-Rating-Avg']]\
.groupby(['Book-Title', 'Book-Author', 'Publisher'], as_index=False).agg({ 'Book-Rating-Avg': ['min', 'max']})
# Out:
#                                              Book-Title  \
#
# 0                             !%@ (A Nutshell handbook)
# 1     'A Hell of a Place to Lose a Cow': An American...
# 2     10,000 dreams interpreted: A dictionary of dreams
# 3                                      101 Famous Poems
# 4                    15 Houseplants Even You Can't Kill
# ...                                                 ...
# 4720                                                Zia
# 4721                                                Zia
# 4722                                Zimmermann Telegram
# 4723  Zoids Chaotic Century (Zoids: Chaotic Century ...
# 4724         Ã?Ã?berleben in der WÃ?ÃÂ¼ste Danakil.
#
#                   Book-Author                       Publisher Book-Rating-Avg  \
#                                                                           min
# 0               Donnalyn Frey                        O'Reilly        0.000000
# 1                 Tim Brookes             National Geographic        0.000000
# 2     Gustavus Hindman Miller       Barnes &amp; Nobles Books        6.666667
# 3                 Roy J. Cook  McGraw-Hill/Contemporary Books        0.000000
# 4                   Joe Elder               Berkley Pub Group        0.000000
# ...                       ...                             ...             ...
# 4720             Scott O'Dell               Laurel-Leaf Books        1.666667
# 4721             Scott O'Dell                  Yearling Books        0.000000
# 4722          Barbara Tuchman                Ballantine Books        0.000000
# 4723           Michiro Ueyama                      Viz Comics       10.000000
# 4724    RÃ?ÃÂ¼diger Nehberg                           Piper        2.666667
#
#
#             max
# 0      6.000000
# 1      3.400000
# 2      7.250000
# 3      5.000000
# 4      0.000000
# ...         ...
# 4720   3.428571
# 4721   2.000000
# 4722   4.000000
# 4723  10.000000
# 4724   5.000000
#
# [4725 rows x 5 columns]

# %% [markdown]
# ### 7. For each book in goodbooks, compute the list of its authors. Assuming that the number of reviews with a text (column work_text_reviews_count) is split equally among all authors, find for each authors the total number of reviews with a text. We will call this quantity the shared number of reviews with a text.

# %% [markdown]
# #### prima soluzione pensata

# %%
##def list_authors(row):
    ##return row['authors'].split(',')

##goodbooks['authors']=goodbooks.apply(list_authors, axis=1)

# %%
##def shared_reviews(row):
    ##return row['work_text_reviews_count']/len(row['authors'])

#goodbooks['shared_number_of_reviews_with_a_text']=goodbooks.apply(shared_reviews, axis=1)
#goodbooks['shared_number_of_reviews_with_a_text']

# %%
##authors_reviews=goodbooks[['authors','shared_number_of_reviews_with_a_text']]
##authors_reviews

# %%
##authors_reviews = authors_reviews.explode('authors')

##authors_reviews.groupby('authors', as_index=False)['shared_number_of_reviews_with_a_text'].sum()

# %% [markdown]
# #### seconda soluzione proposta

# %%
for i, row in goodbooks.iterrows():
    goodbooks.at[i,'authors'] = row["authors"].split(',')
    num_of_authors = len(row["authors"].split(','))
    goodbooks.at[i,'work_text_reviews_count'] = row['work_text_reviews_count'] / num_of_authors

# %%
goodbooks_exploded = goodbooks.explode('authors')

# %%
authors_review= goodbooks_exploded.groupby('authors', as_index=False)['work_text_reviews_count'].sum()
authors_review
# Out:
#                       authors  work_text_reviews_count
# 0              Alan R. Clarke                    27890
# 1     B.M. Mooyaart-Doubleday                     6941
# 2                Bernard Knox                     1620
# 3               CelÃ¢l Ãster                    15172
# 4               David J. Skal                     5754
# ..                        ...                      ...
# 105             Veronica Roth                   156896
# 106           William Golding                    26886
# 107           William Goldman                    15630
# 108       William Shakespeare                     7389
# 109               Yann Martel                    42962
#
# [110 rows x 2 columns]

# %%
authors_review.rename(columns={'work_text_reviews_count': 'shared_number_of_reviews_with_a_text'}, inplace=True)

# %%
authors_review
# Out:
#                       authors  shared_number_of_reviews_with_a_text
# 0              Alan R. Clarke                                 27890
# 1     B.M. Mooyaart-Doubleday                                  6941
# 2                Bernard Knox                                  1620
# 3               CelÃ¢l Ãster                                 15172
# 4               David J. Skal                                  5754
# ..                        ...                                   ...
# 105             Veronica Roth                                156896
# 106           William Golding                                 26886
# 107           William Goldman                                 15630
# 108       William Shakespeare                                  7389
# 109               Yann Martel                                 42962
#
# [110 rows x 2 columns]

# %%
authors_review.sort_values(by='shared_number_of_reviews_with_a_text', ascending=False)
# Out:
#                 authors  shared_number_of_reviews_with_a_text
# 104     Suzanne Collins                                340066
# 100     Stephenie Meyer                                258573
# 70           John Green                                230584
# 105       Veronica Roth                                156896
# 64         J.K. Rowling                                136667
# ..                  ...                                   ...
# 29        Robert Fagles                                  1620
# 6             E.V. Rieu                                  1620
# 2          Bernard Knox                                  1620
# 9     FrÃ©dÃ©ric Mugler                                  1620
# 62                Homer                                  1620
#
# [110 rows x 2 columns]

# %% [markdown]
# ### 8. For each year of publication, determine the author that has the largest value of the shared number of reviews with a text

# %%
goodbooks_exploded.rename(columns={'work_text_reviews_count': 'shared_number_of_reviews_with_a_text'}, inplace=True)

# %%
goodbooks_exploded.groupby('original_publication_year', as_index=False)\
[['shared_number_of_reviews_with_a_text', 'authors']].max()
# Out:
#     original_publication_year  shared_number_of_reviews_with_a_text  \
# 0                      -720.0                                  1620
# 1                      1595.0                                  7389
# 2                      1811.0                                  3842
# 3                      1813.0                                 49152
# 4                      1818.0                                  6664
# 5                      1847.0                                 15606
# 6                      1859.0                                  4364
# 7                      1868.0                                 17090
# 8                      1884.0                                  4149
# 9                      1891.0                                  9823
# 10                     1897.0                                  5754
# 11                     1911.0                                 13054
# 12                     1925.0                                 51992
# 13                     1932.0                                 20095
# 14                     1936.0                                 16050
# 15                     1937.0                                 37653
# 16                     1945.0                                 35472
# 17                     1946.0                                  6134
# 18                     1947.0                                  6941
# 19                     1949.0                                 15172
# 20                     1950.0                                 15186
# 21                     1951.0                                 44920
# 22                     1952.0                                  4348
# 23                     1953.0                                 30694
# 24                     1954.0                                 26886
# 25                     1958.0                                 11000
# 26                     1960.0                                 72586
# 27                     1964.0                                 14368
# 28                     1967.0                                 22662
# 29                     1969.0                                 19646
# 30                     1973.0                                 15630
# 31                     1974.0                                  9234
# 32                     1977.0                                 14936
# 33                     1979.0                                 20345
# 34                     1985.0                                 38054
# 35                     1988.0                                 27890
# 36                     1989.0                                  4239
# 37                     1990.0                                  8143
# 38                     1993.0                                 54084
# 39                     1995.0                                 14915
# 40                     1996.0                                 46205
# 41                     1997.0                                 37933
# 42                     1998.0                                 17086
# 43                     1999.0                                 47116
# 44                     2000.0                                 25112
# 45                     2001.0                                 42962
# 46                     2002.0                                 36642
# 47                     2003.0                                 59730
# 48                     2004.0                                 30719
# 49                     2005.0                                 95009
# 50                     2006.0                                 55732
# 51                     2007.0                                 51589
# 52                     2008.0                                155254
# 53                     2009.0                                 88538
# 54                     2010.0                                 96274
# 55                     2011.0                                101023
# 56                     2012.0                                140739
# 57                     2015.0                                 93600
#
#                         authors
# 0                         Homer
# 1           William Shakespeare
# 2                   Jane Austen
# 3                   Jane Austen
# 4   Mary Wollstonecraft Shelley
# 5                 Emily BrontÃ«
# 6               Charles Dickens
# 7             Louisa May Alcott
# 8                    Mark Twain
# 9                   Oscar Wilde
# 10                  Bram Stoker
# 11      Frances Hodgson Burnett
# 12          F. Scott Fitzgerald
# 13                Aldous Huxley
# 14            Margaret Mitchell
# 15               John Steinbeck
# 16                George Orwell
# 17    Antoine de Saint-ExupÃ©ry
# 18                   Anne Frank
# 19                George Orwell
# 20                   C.S. Lewis
# 21                J.D. Salinger
# 22                   E.B. White
# 23                 Ray Bradbury
# 24              William Golding
# 25                  Elie Wiesel
# 26                   Harper Lee
# 27             Shel Silverstein
# 28                  S.E. Hinton
# 29            Kurt Vonnegut Jr.
# 30              William Goldman
# 31             Shel Silverstein
# 32                 Stephen King
# 33                Douglas Adams
# 34             Orson Scott Card
# 35                 Paulo Coelho
# 36                 John Grisham
# 37             Michael Crichton
# 38                   Lois Lowry
# 39               Philip Pullman
# 40              Nicholas Sparks
# 41                 J.K. Rowling
# 42                 Louis Sachar
# 43              Stephen Chbosky
# 44                 J.K. Rowling
# 45                  Yann Martel
# 46          Christopher Paolini
# 47                  Mark Haddon
# 48                 Jodi Picoult
# 49                Stieg Larsson
# 50                Stieg Larsson
# 51              Stephenie Meyer
# 52              Suzanne Collins
# 53              Suzanne Collins
# 54              Suzanne Collins
# 55                Veronica Roth
# 56                Veronica Roth
# 57                Paula Hawkins

# %% [markdown]
# ### 9. Assuming that there are no errors in the ISBN fields, find the books in both datasets, and compute the difference of average rating according to the ratings and the goodratings datasets

# %%
intersected_books = pd.merge(avg_rating_of_book, goodbooks, how ='inner', left_on ='ISBN', right_on= 'isbn')

# %%
intersected_books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Book-Rating', 'book_id',
#        'goodreads_book_id', 'best_book_id', 'work_id', 'books_count', 'isbn',
#        'isbn13', 'authors', 'original_publication_year', 'original_title',
#        'title', 'language_code', 'average_rating', 'ratings_count',
#        'work_ratings_count', 'work_text_reviews_count', 'ratings_1',
#        'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5', 'image_url',
#        'small_image_url'],
#       dtype='object')

# %%
intersected_books['ratings_difference'] = intersected_books['Book-Rating'] - intersected_books['average_rating']

# %%
intersected_books[['ISBN','Book-Title', 'ratings_difference']]
# Out:
#          ISBN                                         Book-Title  \
# 0  014028009X                              Bridget Jones's Diary
# 1  014038572X                      The Outsiders (Now in Speak!)
# 2  043965548X  Harry Potter and the Prisoner of Azkaban (Harr...
# 3  1400032717  The Curious Incident of the Dog in the Night-T...
# 4  1594480001                                    The Kite Runner
#
#    ratings_difference
# 0            0.001852
# 1            0.400674
# 2           -0.996667
# 3            0.963187
# 4           -1.860000

# %% [markdown]
# ### 10. Split the users dataset according to the age. One dataset contains the users with unknown age, one with age 0-14, one with age 15-24, one with age 25-34, and so on

# %%
users_unknown = users[users['Age'].isnull() == True]
users_0_14 = users[(users['Age']>=0) & (users['Age']<15)]

max_value = users['Age'].max()
multiplier = 10

for i in range(15, int(max_value)+1, 10):
    globals()[f"users_{i}_{i+multiplier-1}"] = users[(users['Age']>=i) & (users['Age']<i+multiplier)]

# %%
users_unknown
# Out:
#         User-ID                            Location  Age         city  \
# 0             1                  nyc, new york, usa  NaN          nyc
# 2             3     moscow, yukon territory, russia  NaN       moscow
# 4             5  farnborough, hants, united kingdom  NaN  farnborough
# 6             7                 washington, dc, usa  NaN   washington
# 7             8            timmins, ontario, canada  NaN      timmins
# ...         ...                                 ...  ...          ...
# 278849   278850          sergnano, lombardia, italy  NaN     sergnano
# 278853   278854               portland, oregon, usa  NaN     portland
# 278855   278856           brampton, ontario, canada  NaN     brampton
# 278856   278857           knoxville, tennessee, usa  NaN    knoxville
# 278857   278858                dublin, n/a, ireland  NaN       dublin
#
#                   region          country
# 0               new york              usa
# 2        yukon territory           russia
# 4                  hants   united kingdom
# 6                     dc              usa
# 7                ontario           canada
# ...                  ...              ...
# 278849         lombardia            italy
# 278853            oregon              usa
# 278855           ontario           canada
# 278856         tennessee              usa
# 278857               n/a          ireland
#
# [110762 rows x 6 columns]

# %%
users_0_14
# Out:
#         User-ID                           Location   Age               city  \
# 10           11     melbourne, victoria, australia  14.0          melbourne
# 18           19                          weston, ,  14.0             weston
# 40           41            santee, california, usa  14.0             santee
# 119         120    villeneuve d`ascq, nord, france  13.0  villeneuve d`ascq
# 219         220           bogota, bogota, colombia   0.0             bogota
# ...         ...                                ...   ...                ...
# 278574   278575  burnaby, british columbia, canada  14.0            burnaby
# 278582   278583              steele, missouri, usa  13.0             steele
# 278668   278669          spring hill, fl, hernando  13.0        spring hill
# 278751   278752        london, nova scotia, canada   9.0             london
# 278793   278794           st. paul, minnesota, usa  14.0           st. paul
#
#                    region     country
# 10               victoria   australia
# 18
# 40             california         usa
# 119                  nord      france
# 219                bogota    colombia
# ...                   ...         ...
# 278574   british columbia      canada
# 278582           missouri         usa
# 278668                 fl    hernando
# 278751        nova scotia      canada
# 278793          minnesota         usa
#
# [4313 rows x 6 columns]

# %%
users_35_44
# Out:
#         User-ID                           Location   Age  \
# 53           54              eubank, kentucky, usa  44.0
# 66           67     framingham, massachusetts, usa  43.0
# 69           70           rochester, new york, usa  44.0
# 74           75        long beach, california, usa  37.0
# 84           85    london, england, united kingdom  41.0
# ...         ...                                ...   ...
# 278794   278795        santa pola, alicante, spain  35.0
# 278797   278798               stayton, oregon, usa  39.0
# 278807   278808  esplugas de llobregat, n/a, spain  43.0
# 278813   278814          san jose, california, usa  35.0
# 278823   278824           madison, new jersey, usa  41.0
#
#                          city          region          country
# 53                     eubank        kentucky              usa
# 66                 framingham   massachusetts              usa
# 69                  rochester        new york              usa
# 74                 long beach      california              usa
# 84                     london         england   united kingdom
# ...                       ...             ...              ...
# 278794             santa pola        alicante            spain
# 278797                stayton          oregon              usa
# 278807  esplugas de llobregat             n/a            spain
# 278813               san jose      california              usa
# 278823                madison      new jersey              usa
#
# [32690 rows x 6 columns]

# %% [markdown]
# ### 11. Find the books that appear only in the goodbooks datasets

# %%
lista= []
books_ISBN = books['ISBN'].tolist()
for codice in goodbooks['isbn']:
    if codice not in books_ISBN:
        lista.append(codice)
lista
# Out:
# ['439023483',
#  '439554934',
#  '316015849',
#  '61120081',
#  '743273567',
#  '525478817',
#  '618260307',
#  '316769177',
#  '1416524797',
#  '679783261',
#  '62024035',
#  '451524934',
#  '452284244',
#  '553296981',
#  '307269752',
#  '439023491',
#  '618346252',
#  '439023513',
#  '439358078',
#  '316166685',
#  '439064864',
#  '439139600',
#  '545010225',
#  '307277674',
#  '439785960',
#  '140283331',
#  '743477111',
#  '297859382',
#  '399155341',
#  '142000671',
#  '739326228',
#  '1612130291',
#  '61122416',
#  '385732554',
#  '60764899',
#  '965818675',
#  '553588486',
#  '143038419',
#  '786838655',
#  '451529308',
#  '142437204',
#  '553816713',
#  '770430074',
#  '1565125606',
#  '375831002',
#  '307347974',
#  '316160199',
#  '60513039',
#  '1416914285',
#  '316160202',
#  '375826696',
#  '345391802',
#  '60929871',
#  '031606792X',
#  '142001740',
#  '142437174',
#  '64410935',
#  '1594633665',
#  '679879242',
#  '393978893',
#  '743454537',
#  '385333846',
#  '446675539',
#  '1594489505',
#  '671027344',
#  '7442912',
#  '812550706',
#  '141439475',
#  '450040186',
#  '316068047',
#  '142402516',
#  '141439661',
#  '439244196',
#  '307275558',
#  '143039954',
#  '156012197',
#  '074324754X',
#  '385486804',
#  '141439602',
#  '030734813X',
#  '60256656',
#  '385338600',
#  '374500010',
#  '014241493X',
#  '345418263',
#  '385737947',
#  '61234001',
#  '517189607',
#  '60531045',
#  '375751513',
#  '345803507',
#  '393970124',
#  '307269981',
#  '1612130585']

# %%
only_goodbooks = goodbooks[goodbooks['isbn'].isin(lista)]
only_goodbooks
# Out:
#     book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0         1            2767052       2767052   2792775          272
# 1         2                  3             3   4640799          491
# 2         3              41865         41865   3212258          226
# 3         4               2657          2657   3275794          487
# 4         5               4671          4671    245494         1356
# ..      ...                ...           ...       ...          ...
# 94       95               5297          5297   1858012         2303
# 95       96           13536860      13536860  18034963          133
# 96       97              17245         17245   3165724         2207
# 97       98            5060378       5060378   6976108          209
# 98       99           11857408      11857408  16813814          147
#
#           isbn        isbn13                                        authors  \
# 0    439023483  9.780439e+12                              [Suzanne Collins]
# 1    439554934  9.780440e+12                [J.K. Rowling,  Mary GrandPrÃ©]
# 2    316015849  9.780316e+12                              [Stephenie Meyer]
# 3     61120081  9.780061e+12                                   [Harper Lee]
# 4    743273567  9.780743e+12                          [F. Scott Fitzgerald]
# ..         ...           ...                                            ...
# 94   375751513  9.780376e+12              [Oscar Wilde,  Jeffrey Eugenides]
# 95   345803507  9.780346e+12                                   [E.L. James]
# 96   393970124  9.780394e+12  [Bram Stoker,  Nina Auerbach,  David J. Skal]
# 97   307269981  9.780307e+12                  [Stieg Larsson,  Reg Keeland]
# 98  1612130585  9.781612e+12                                   [E.L. James]
#
#     original_publication_year                            original_title  ...  \
# 0                      2008.0                          The Hunger Games  ...
# 1                      1997.0  Harry Potter and the Philosopher's Stone  ...
# 2                      2005.0                                  Twilight  ...
# 3                      1960.0                     To Kill a Mockingbird  ...
# 4                      1925.0                          The Great Gatsby  ...
# ..                        ...                                       ...  ...
# 94                     1891.0                The Picture of Dorian Gray  ...
# 95                     2012.0                        Fifty Shades Freed  ...
# 96                     1897.0                                   Dracula  ...
# 97                     2006.0               Flickan som lekte med elden  ...
# 98                     2011.0                       Fifty Shades Darker  ...
#
#    ratings_count work_ratings_count  work_text_reviews_count  ratings_1  \
# 0        4780653            4942365                   155254      66715
# 1        4602479            4800065                    37933      75504
# 2        3866839            3916824                    95009     456191
# 3        3198671            3340896                    72586      60427
# 4        2683664            2773745                    51992      86236
# ..           ...                ...                      ...        ...
# 94        590014             674551                     9823       9825
# 95        387290             610116                    25287      39079
# 96        618973             689739                     5754      11756
# 97        563994             649253                    15711       4623
# 98        552059             623340                    28052      37245
#
#     ratings_2  ratings_3  ratings_4  ratings_5  \
# 0      127936     560092    1481305    2706317
# 1      101676     455024    1156318    3011543
# 2      436802     793319     875073    1355439
# 3      117415     446835    1001952    1714267
# 4      197621     606158     936012     947718
# ..        ...        ...        ...        ...
# 94      30735     129420     246892     257679
# 95      55691     109963     140304     265079
# 96      36719     151396     246043     243825
# 97      15781      91021     258236     279592
# 98      58935     114203     150906     262051
#
#                                             image_url  \
# 0   https://images.gr-assets.com/books/1447303603m...
# 1   https://images.gr-assets.com/books/1474154022m...
# 2   https://images.gr-assets.com/books/1361039443m...
# 3   https://images.gr-assets.com/books/1361975680m...
# 4   https://images.gr-assets.com/books/1490528560m...
# ..                                                ...
# 94  https://images.gr-assets.com/books/1424596966m...
# 95  https://images.gr-assets.com/books/1336418837m...
# 96  https://images.gr-assets.com/books/1387151694m...
# 97  https://images.gr-assets.com/books/1351778881m...
# 98  https://images.gr-assets.com/books/1358266080m...
#
#                                       small_image_url
# 0   https://images.gr-assets.com/books/1447303603s...
# 1   https://images.gr-assets.com/books/1474154022s...
# 2   https://images.gr-assets.com/books/1361039443s...
# 3   https://images.gr-assets.com/books/1361975680s...
# 4   https://images.gr-assets.com/books/1490528560s...
# ..                                                ...
# 94  https://images.gr-assets.com/books/1424596966s...
# 95  https://images.gr-assets.com/books/1336418837s...
# 96  https://images.gr-assets.com/books/1387151694s...
# 97  https://images.gr-assets.com/books/1351778881s...
# 98  https://images.gr-assets.com/books/1358266080s...
#
# [94 rows x 23 columns]

# %% [markdown]
# ### 12. Assuming that each pair (author, title) identifies a book, for each book find the number of times it appears in the books dataset. Which books appear the most times?

# %%
books_times = books.groupby(['Book-Title', 'Book-Author'], as_index=False).size()

# %%
books_times.iloc[books_times['size'].idxmax()]
# Out:
# Book-Title          Little Women
# Book-Author    Louisa May Alcott
# size                          21
# Name: 113850, dtype: object

# %%
books_times.loc[books_times['size']>=books_times['size'].max()]
# Out:
#           Book-Title        Book-Author  size
# 113850  Little Women  Louisa May Alcott    21

# %% [markdown]
# ### 13. Find the author with the highest average rating according to the goodbooks datasets

# %%
authors_max_average_rating = goodbooks_exploded.groupby('authors', as_index=False)['average_rating'].mean()

# %%
authors_max_average_rating.loc[authors_max_average_rating['average_rating']>=
                               authors_max_average_rating['average_rating'].max()]
# Out:
#         authors  average_rating
# 32   Rufus Beck            4.53
